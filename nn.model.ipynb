# %%
import torch
import torch.nn as nn

class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.w = nn.Parameter(torch.tensor(0.0))

    def forward(self, x):
        return self.w * x

# %%
import torch
import torch.nn as nn
layer = nn.Linear(3, 2)
x = torch.tensor([[1.0, 2.0, 3.0,]])
y = layer(x)
print(y)
# Out:
# tensor([[ 1.2457, -1.7258]], grad_fn=<AddmmBackward0>)

# %%
import torch
import torch.nn as nn

# Model
model = nn.Linear(3, 1)

# Example input: [height, weight, age]
x = torch.tensor([170.0, 65.0, 25.0])

# Forward pass
risk_score = model(x)

print(risk_score)
# Out:
# tensor([-46.8780], grad_fn=<ViewBackward0>)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Model
class MyModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        return self.linear(x)

# Data (2D tensor)
x = torch.tensor([[1.], [2.], [3.], [4.]])
y = torch.tensor([[2.], [4.], [6.], [8.]])

# Model, loss, optimizer
model = MyModel()
loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.1)

# Training loop
for epoch in range(10):
    optimizer.zero_grad()
    y_pred = model(x)
    loss = loss_fn(y_pred, y)
    loss.backward()
    optimizer.step()

    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 52.9015
# Epoch 2, Loss: 47.7473
# Epoch 3, Loss: 42.8711
# Epoch 4, Loss: 38.2774
# Epoch 5, Loss: 33.9696
# Epoch 6, Loss: 29.9500
# Epoch 7, Loss: 26.2199
# Epoch 8, Loss: 22.7793
# Epoch 9, Loss: 19.6268
# Epoch 10, Loss: 16.7596
